# %%
import requests
import random
import json
import pprint
import time
from datetime import datetime
from bs4 import BeautifulSoup

class Crawler:
    pttUrl = "https://www.ptt.cc"

    def __init__(self, board):
        self.board = board
        self.Articles = []
        self.boardUrl = "/bbs/{}".format(board)
        self.contents = []
#         request = requests.get(Crawler.pttUrl + self.boardUrl, cookies = {"over18": "1"})
#         if request.status_code == 404:
#             print("No such board")
#             return
#         pageText = crawler.pageText.split("r-list-sep")[0]
#         self.pageText = request.text
        
    def getToday(self, date=None, pageNext=None, keyword=None, num_posts=1000):
        if pageNext == None:
            pageNext = self.boardUrl
        request = requests.get(Crawler.pttUrl + pageNext, cookies = {"over18": "1"})
        time.sleep(random.random()*3)
        if request.status_code == 404:
            print("No such board")
            return
        self.pageText = request.text
        soup = BeautifulSoup(self.pageText, "lxml")
        pageNext = soup.find("div", "btn-group btn-group-paging").find_all("a")[1].attrs["href"]
        if date == None:
            date = datetime(2020, 1, 1) 
        pageText = self.pageText.split("r-list-sep")[0]
        soup = BeautifulSoup(pageText, "lxml")
        for post in soup.select("div.r-ent"):
            url = post.find("div", "title").a
            if url == None:
                continue
            else:
                url = post.find("div", "title").a.attrs["href"]
            articleTxt = requests.get(Crawler.pttUrl + url, cookies = {"over18": "1"}).text
            articleSoup = BeautifulSoup(articleTxt, "lxml")
            title = articleSoup.find("title").text  # 標題
            content = articleSoup.find("meta", property="og:description").get("content")  # 文章內容
            if title == None or content == None:
                continue
            if keyword != None:
                if title.find(keyword) < 0 and content.find(keyword) < 0:
                    continue
            print(Crawler.pttUrl + url)
#             print(type(title))
            self.contents.append(title + ":" + content)
#             self.contents.append(content)
            push_list = []
            for push in articleSoup.find_all("span", class_="push-content"):
                if len(push.text[2:]) <= 0:
                    continue
                push_list.append(push.text[2:])  # 推文
            self.contents.append(push_list)  
            time_str = post.find("div", "date").text.strip()
            time_obj = datetime.strptime(time_str+"/2020", '%m/%d/%Y')
            #if True:  # 一篇文章
            if time_obj < date:  # 不是今天的文章
                return
        else:
            if len(self.contents)/2 > num_posts:
                return
            print(pageNext)
            self.getToday(date, pageNext, keyword, num_posts)
            
class ArticleInfo:
    def __init__(self, **kwargs):
        self.title = kwargs.get('title', None)
        self.author = kwargs.get('author', None)
        self.url = kwargs.get('url', None)
        self.time = kwargs.get('time', None)
        self.push_message = dict()
        self.content = None
        self.res = None

    def data_process(info, board):
        data = []
        for index, article in enumerate(info):
            data.append(
                {
                    "作者": article.author,
                    "標題": article.title,
                    "日期": article.time,
                    "ip": article.ip,
                    "內文": article.content,
                    "推文": article.push_text
                }
            )
         
        json_data = json.dumps(data, indent=4, sort_keys=True, ensure_ascii=False)
        file_name = 'data-{}-{}.json'.format(board, datetime.datetime.now().strftime('%Y%m%d%H%M%S'))
        with open(file_name, 'a', encoding='utf-8') as f:
            f.write(json_data)

# %%
board = "car"
crawler = Crawler(board)
crawler.getToday(keyword="車", num_posts=1)
# Out:
# https://www.ptt.cc/bbs/car/M.1608121523.A.3A7.html
# https://www.ptt.cc/bbs/car/M.1608122075.A.EF1.html
# https://www.ptt.cc/bbs/car/M.1608122485.A.945.html
# https://www.ptt.cc/bbs/car/M.1608125443.A.061.html
# https://www.ptt.cc/bbs/car/M.1608127448.A.ABB.html
# https://www.ptt.cc/bbs/car/M.1608127699.A.CAA.html
# https://www.ptt.cc/bbs/car/M.1608129161.A.E6E.html
# https://www.ptt.cc/bbs/car/M.1608130140.A.7AF.html
# https://www.ptt.cc/bbs/car/M.1608159874.A.804.html
# https://www.ptt.cc/bbs/car/M.1608166715.A.F4E.html
# https://www.ptt.cc/bbs/car/M.1608167175.A.117.html

# %%
print(len(crawler.contents))
# Out:
# 16

# %%
import tensorflow as tf
from ckiptagger import data_utils, construct_dictionary, WS, POS, NER

import os
import sys

# Suppress as many warnings as possible
# os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
# from tensorflow.python.util import deprecation
# deprecation._PRINT_DEPRECATION_WARNINGS = False
# import tensorflow as tf
# tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
ws = WS("./data", disable_cuda=False)
pos = POS("./data", disable_cuda=False)
ner = NER("./data", disable_cuda=False)

# %%
word_sentence_list = ws(
    crawler.contents,
    sentence_segmentation=True, # To consider delimiters
    segment_delimiter_set = {",", "。", ":", "?", "!", ";", ".", "（", "）", "", "()", " [",
        "] ", ":", "", "》"}, # This is the defualt set of delimiters
#     recommend_dictionary = dictionary1, # words in this dictionary are encouraged
#     coerce_dictionary = dictionary2, # words in this dictionary are forced
)

pos_sentence_list = pos(word_sentence_list)

entity_sentence_list = ner(word_sentence_list, pos_sentence_list)

del ws
del pos
del ner

# %%
def print_word_pos_sentence(word_sentence, pos_sentence):
    assert len(word_sentence) == len(pos_sentence)
    for word, pos in zip(word_sentence, pos_sentence):
        print(f"{word}({pos})", end="\u3000")
    print()
    return
    
for i, sentence in enumerate(word_sentence_list):
    print()
    print(f"'{sentence}'")
    print_word_pos_sentence(word_sentence_list[i],  pos_sentence_list[i])
    for entity in sorted(entity_sentence_list[i]):
        print(entity)
# Out:
# '['「', '問題', '」', '三', '代', 'elantra', '冷氣', '壓縮機', ' - ', '看板', ' car - ', '批踢踢', '實業坊', ':', '現代', '三', '代', 'elantra', '冷氣', '壓縮機', '和', '後面', '5', '.', '6', '代', '有', '一樣', '嗎', '？', '還是', '和', '那', '個', '車款', '共用', '可', '直上', '？', '\n', '因為', '車子', '少', '開', '但', '車況', '很', '好', '，', '只是', '壓縮機', '壞掉', '而已', '，', '但', '車子', '沒', '什麼', '殘值', '，', '想', '說', '殺', '肉', '的', '用', '一', '用', '\n', '就', '好', '。', '\n--\n', '※ ', '發信站', ':', ' ', '批', '踢踢', '實業坊', '(', 'ptt', '.', 'cc', ')', ',', ' ', '來自', ':', ' 123', '.', '110', '.', '250', '.', '154', ' ', '(', '臺灣', ')', '\n']'
# 「(PARENTHESISCATEGORY)　問題(Na)　」(PARENTHESISCATEGORY)　三(Neu)　代(Na)　elantra(FW)　冷氣(Na)　壓縮機(Na)　 - (FW)　看板(Na)　 car - (FW)　批踢踢(Na)　實業坊(Nc)　:(COLONCATEGORY)　現代(Nd)　三(Neu)　代(Na)　elantra(FW)　冷氣(Na)　壓縮機(Na)　和(Caa)　後面(Ncd)　5(Neu)　.(PERIODCATEGORY)　6(Neu)　代(Na)　有(V_2)　一樣(VH)　嗎(T)　？(QUESTIONCATEGORY)　還是(D)　和(P)　那(Nep)　個(Nf)　車款(Na)　共用(VC)　可(D)　直上(VCL)　？(QUESTIONCATEGORY)
# (WHITESPACE)　因為(Cbb)　車子(Na)　少(D)　開(VC)　但(Cbb)　車況(Na)　很(Dfa)　好(VH)　，(COMMACATEGORY)　只是(Cbb)　壓縮機(Na)　壞掉(VH)　而已(T)　，(COMMACATEGORY)　但(Cbb)　車子(Na)　沒(VJ)　什麼(Nep)　殘值(Na)　，(COMMACATEGORY)　想(VE)　說(VE)　殺(VC)　肉(Na)　的(DE)　用(VC)　一(D)　用(VC)
# (WHITESPACE)　就(D)　好(VH)　。(PERIODCATEGORY)
# --
# (FW)　※ (FW)　發信站(Nc)　:(COLONCATEGORY)　 (WHITESPACE)　批(VC)　踢踢(VC)　實業坊(Nc)　((PARENTHESISCATEGORY)　ptt(FW)　.(PERIODCATEGORY)　cc(FW)　)(PARENTHESISCATEGORY)　,(COMMACATEGORY)　 (WHITESPACE)　來自(VJ)　:(COLONCATEGORY)　 123(Neu)　.(PERIODCATEGORY)　110(Neu)　.(PERIODCATEGORY)　250(Neu)　.(PERIODCATEGORY)　154(Neu)　 (WHITESPACE)　((PARENTHESISCATEGORY)　臺灣(Nc)　)(PARENTHESISCATEGORY)
# (WHITESPACE)
# (56, 59, 'CARDINAL', '5.6')
#
# '['問問看韓國大盤館？']'
# 問問看韓國大盤館？(VA)
# (3, 8, 'FAC', '韓國大盤館')
#
# '['[', '問題', '] ', '和泰', '煞車', '總泵', '服務', '通知', ' - ', '看板', ' car - ', '批踢踢', '實業坊', ':', '加', '魚', '真的', '好', '棒棒', '，', '厲害', '厲害', '\n', '讓', '和泰', '這', '個', '大', '財團', '讓', '步\n', '希望', '能', '連任', '\n', '只是', '有點', '看', '不', '太', '懂', '這', '個', '說明', '\n', '他', '意思', '是', '上列', '車型', '的', '煞車', '總泵', '即日', '起', '\n']'
# [(PARENTHESISCATEGORY)　問題(Na)　] (FW)　和泰(Nb)　煞車(Na)　總泵(Na)　服務(VC)　通知(VC)　 - (FW)　看板(Na)　 car - (FW)　批踢踢(Na)　實業坊(Nc)　:(COLONCATEGORY)　加(VC)　魚(Na)　真的(D)　好(VH)　棒棒(Neqa)　，(COMMACATEGORY)　厲害(VH)　厲害(VH)
# (WHITESPACE)　讓(VL)　和泰(Nb)　這(Nep)　個(Nf)　大(VH)　財團(Na)　讓(VL)　步
# (Nb)　希望(VK)　能(D)　連任(VG)
# (WHITESPACE)　只是(D)　有點(Dfa)　看(VJ)　不(D)　太(Dfa)　懂(VJ)　這(Nep)　個(Nf)　說明(VE)
# (WHITESPACE)　他(Nh)　意思(Na)　是(SHI)　上列(A)　車型(Na)　的(DE)　煞車(Na)　總泵(Na)　即日(Nd)　起(Ng)
# (WHITESPACE)
# (5, 7, 'ORG', '和泰')
#
# '['連任別想，民進黨會先清算她，誰叫她大義滅親...', '以前Premio有做過總泵召回  2007 2008 XV40上市左右', '許多人大大感動 Toyota會召回最老1997的車 11years', '予以處理', '看說明不像召回啊！沒壞的話就先不用換吧！', '這是服務活動，不是召回，標題請改正一下', '有壞才有', '如果壞的機率很低，提供終身保固也增加不了多少成本', '問題是，如果行駛途中故障還是很危險啊', '另外這個服務到底有沒有期限？', '行駛中突然沒煞車這種重大安全瑕疵絕對構成召回，', '你可以想想為何美日都沒召回', '了不起，負責，良心企業', '良心個阿鬼 如果沒有高施壓 最好會']'
# 連任別想，民進黨會先清算她，誰叫她大義滅親...(D)　以前Premio有做過總泵召回  2007 2008 XV40上市左右(Nb)　許多人大大感動 Toyota會召回最老1997的車 11years(Nb)　予以處理(VA)　看說明不像召回啊！沒壞的話就先不用換吧！(D)　這是服務活動，不是召回，標題請改正一下(VH)　有壞才有(VH)　如果壞的機率很低，提供終身保固也增加不了多少成本(VH)　問題是，如果行駛途中故障還是很危險啊(VH)　另外這個服務到底有沒有期限？(FW)　行駛中突然沒煞車這種重大安全瑕疵絕對構成召回，(VH)　你可以想想為何美日都沒召回(VH)　了不起，負責，良心企業(VH)　良心個阿鬼 如果沒有高施壓 最好會(Nc)
# (5, 8, 'ORG', '民進黨')
# (9, 12, 'PERSON', '先清算')
#
# '['[', '問題', '] ', '買', '二手車', '"', '退', '強制險', '"', '到', '(', '新', '車主', ')', '帳戶', '?', ' - ', '看板', ' car - ', '批踢踢', '實業坊', ':', '大家', '好\n', '今天', '向', '中古', '車商', '購入', '2005', 'WISH\n', '已', '付', '訂金', '並', '簽約', '，', '給', '車商', '我', '的', '雙', '證件', '(', '身分證', '、', '駕照', ')', '，', '沒有', '印章\n', '談妥', '後', '要', '離開', '車商', '，', '忽然', '說', '要', '我', '的', '銀行', '帳戶', '影本', '或', '照片\n', '說', '什麼', '這樣', '才', '能夠', '退強', '制險', '到', '我', '戶口', '?', '\n']'
# [(PARENTHESISCATEGORY)　問題(Na)　] (FW)　買(VC)　二手車(Na)　"(FW)　退(VD)　強制險(Na)　"(FW)　到(Caa)　((PARENTHESISCATEGORY)　新(VH)　車主(Na)　)(PARENTHESISCATEGORY)　帳戶(Na)　?(QUESTIONCATEGORY)　 - (FW)　看板(Na)　 car - (FW)　批踢踢(Na)　實業坊(Nc)　:(COLONCATEGORY)　大家(Nh)　好
# (Nb)　今天(Nd)　向(P)　中古(A)　車商(Na)　購入(VC)　2005(Nd)　WISH
# (FW)　已(D)　付(VD)　訂金(Na)　並(Cbb)　簽約(VA)　，(COMMACATEGORY)　給(VD)　車商(Na)　我(Nh)　的(DE)　雙(A)　證件(Na)　((PARENTHESISCATEGORY)　身分證(Na)　、(PAUSECATEGORY)　駕照(Na)　)(PARENTHESISCATEGORY)　，(COMMACATEGORY)　沒有(VJ)　印章
# (Na)　談妥(VC)　後(Ng)　要(D)　離開(VC)　車商(Na)　，(COMMACATEGORY)　忽然(D)　說(VE)　要(VE)　我(Nh)　的(DE)　銀行(Nc)　帳戶(Na)　影本(Na)　或(Caa)　照片
# (Na)　說(VE)　什麼(Nep)　這樣(VH)　才(Da)　能夠(D)　退強(VH)　制險(VA)　到(P)　我(Nh)　戶口(Na)　?(QUESTIONCATEGORY)
# (WHITESPACE)
# (50, 52, 'ORG', '中古')
# (56, 60, 'DATE', '2005')
#
# '['不用給吧？你都還沒開始保強制險是要退啥？', '我怎麼記得任意險才是跟人 強制險是跟車的', '車主是誰就退誰，主打買車送強制險退費？', '幹嘛退強制險給你？ 直接辦理保險過戶就好的事情，', '大不了不退就不退，反正不是自己出的錢', '小施正在FB直播  你可以線上問他', '有問了一些前輩~好像是保險批改，退差額', '如果是差額，通常也沒多少錢，除非原車主記錄很差', '汽車到監理站過戶前 強制險要先過戶給新車主 所以強制險的權利就變成你了 若規章保費低於原本車主 退費', '就會屬於你這個新車主 若高於原本車主 就要補收差額', ' 車行應該也不能肯定要補要退 先收資料比較省事', '感謝樓上詳細解說~!!!Y', '你的強制險跟前車主是同一家嗎？若你還沒加保，前車主又願意送給你，過戶時就全過給你了呀。如果你們不同家產險，是前車主自己要去產險分公司窗口親自辦理', '退款。根本不用給存摺影本啥的呀！', '不放心就跟車行說你會自己去退。退那個又不費時~']'
# 不用給吧？你都還沒開始保強制險是要退啥？(VH)　我怎麼記得任意險才是跟人 強制險是跟車的(FW)　車主是誰就退誰，主打買車送強制險退費？(Nb)　幹嘛退強制險給你？ 直接辦理保險過戶就好的事情，(VH)　大不了不退就不退，反正不是自己出的錢(VH)　小施正在FB直播  你可以線上問他(Na)　有問了一些前輩~好像是保險批改，退差額(Na)　如果是差額，通常也沒多少錢，除非原車主記錄很差(VH)　汽車到監理站過戶前 強制險要先過戶給新車主 所以強制險的權利就變成你了 若規章保費低於原本車主 退費(Nb)　就會屬於你這個新車主 若高於原本車主 就要補收差額(FW)　 車行應該也不能肯定要補要退 先收資料比較省事(FW)　感謝樓上詳細解說~!!!Y(VH)　你的強制險跟前車主是同一家嗎？若你還沒加保，前車主又願意送給你，過戶時就全過給你了呀。如果你們不同家產險，是前車主自己要去產險分公司窗口親自辦理(VH)　退款。根本不用給存摺影本啥的呀！(VA)　不放心就跟車行說你會自己去退。退那個又不費時~(Dk)
#
# '['[', '問題', '] ', '汽車', '電瓶', '可以', '用', '多久', '?', ' - ', '看板', ' car - ', '批踢踢', '實業坊', ':', '個人', '偏好', '統力', '，', '一般', '使用', '壽命', '4', '~', '5', '年', '，', '目前', '使用', '這', '顆', '也', '約', '5', '年', '。', '\n', '因為', '懶得', '保養', '，', '都', '習慣', '用', '免', '加', '水', '。', '\n', '下', '次', '打算', '換', '湯', '淺', '電池', '比較', '便宜', '，', '也', '有', '人', '說', '愛馬龍', 'AMARON ', '銀合金', '高效能', '電瓶', '不錯', '用', '?', '\n', '韓製', '電瓶', '我', '不', '敢', '用', '，', '國際牌', ' PANASONIC ', '沒用', '過', '.', '.', '.', '\n', '請問', '大家', '汽車', '電瓶', '可以', '用', '多久', '?', ' ', '各位', '有沒有', '推薦', '分享', '一', '下\n']'
# [(PARENTHESISCATEGORY)　問題(Na)　] (FW)　汽車(Na)　電瓶(Na)　可以(D)　用(VC)　多久(Nd)　?(QUESTIONCATEGORY)　 - (FW)　看板(Na)　 car - (FW)　批踢踢(Na)　實業坊(Nc)　:(COLONCATEGORY)　個人(Nh)　偏好(VJ)　統力(Nb)　，(COMMACATEGORY)　一般(D)　使用(VC)　壽命(Na)　4(Neu)　~(Caa)　5(Neu)　年(Nf)　，(COMMACATEGORY)　目前(Nd)　使用(VC)　這(Nep)　顆(Nf)　也(D)　約(Da)　5(Neu)　年(Nf)　。(PERIODCATEGORY)
# (WHITESPACE)　因為(Cbb)　懶得(VL)　保養(VC)　，(COMMACATEGORY)　都(D)　習慣(VL)　用(P)　免(D)　加(VC)　水(Na)　。(PERIODCATEGORY)
# (WHITESPACE)　下(Nes)　次(Nf)　打算(VF)　換(VC)　湯(Na)　淺(VH)　電池(Na)　比較(Dfa)　便宜(VH)　，(COMMACATEGORY)　也(D)　有(V_2)　人(Na)　說(VE)　愛馬龍(Na)　AMARON (FW)　銀合金(Na)　高效能(Na)　電瓶(Na)　不錯(VH)　用(VC)　?(QUESTIONCATEGORY)
# (WHITESPACE)　韓製(A)　電瓶(Na)　我(Nh)　不(D)　敢(VL)　用(VC)　，(COMMACATEGORY)　國際牌(Nb)　 PANASONIC (FW)　沒用(VH)　過(Di)　.(PERIODCATEGORY)　.(PERIODCATEGORY)　.(PERIODCATEGORY)
# (WHITESPACE)　請問(VE)　大家(Nh)　汽車(Na)　電瓶(Na)　可以(D)　用(VC)　多久(Nd)　?(QUESTIONCATEGORY)　 (WHITESPACE)　各位(Nh)　有沒有(D)　推薦(VC)　分享(VJ)　一(Neu)　下
# (Na)
# (47, 51, 'DATE', '4~5年')
# (130, 133, 'ORG', '國際牌')
#
# '['避震有問題的車 硬如鐵棒那種 鉛板可以震出裂縫', '電池可能很快就壞掉 這也是一種電池壞法', '一年半往生 在花蓮慈大顧路QQ', '最爛至少也有1年以上', '老化的原廠避震器並不會加劇電瓶的老化；過硬的才會', '比較好奇車友用撐過3年以上的電瓶是什麼廠牌型號熱是一大殺手 放後車廂的壽命 通常會比在引擎室的來', '的長 但現在多了怠速熄火功能 一般說法超過兩年都算', '可以了', '現在的車動不動就怠速熄火，CCS,keyless電瓶壽命有', '兩年就及格了。以前電子設備沒這麼多的年代，一顆加', '水電瓶，會顧的話用個五年八年是基本的。', '電裝品越少 待命品越少的車 電池越耐用', 'GS蠻不錯的', '看行駛路況，常短途跑一定壽命不長', '新車出廠2y10m 還在服役', '感覺偶爾開個長途，電瓶根本很難壞掉阿，隨便用都', '超過五年', '新車三年 舊車沒試過 舊車都用殺肉電瓶', 'AGM會不會比一般鉛酸電池耐用？', '用五年 電壓看起來還行', '韓製不敢用 然後想用印度製？', '其實掛點的，用麻X慢充個四五天，能回充的，至少可以再用一個周期，只是很多新車無法斷電換電瓶，充滿', '風險', '長紅燈進N檔，甚至關大燈，有助於市區的回充', 'keyless有車庫，可進入省電模式', 'focusmk4 聽到很多一年半掛掉的', '怠速熄火就是折磨電池', '我下一顆打算試看看鋰鐵電池', '用過Varta  Deta  都超過三年', '愛馬龍100D用了四年壽命剩50%車報廢拆下,放著一年半', '之後去測還有38%', '11年了還沒換過']'
# 避震有問題的車 硬如鐵棒那種 鉛板可以震出裂縫(VA)　電池可能很快就壞掉 這也是一種電池壞法(Na)　一年半往生 在花蓮慈大顧路QQ(Neqa)　最爛至少也有1年以上(VH)　老化的原廠避震器並不會加劇電瓶的老化；過硬的才會(Na)　比較好奇車友用撐過3年以上的電瓶是什麼廠牌型號熱是一大殺手 放後車廂的壽命 通常會比在引擎室的來(Nc)　的長 但現在多了怠速熄火功能 一般說法超過兩年都算(Na)　可以了(Na)　現在的車動不動就怠速熄火，CCS,keyless電瓶壽命有(Na)　兩年就及格了。以前電子設備沒這麼多的年代，一顆加(VH)　水電瓶，會顧的話用個五年八年是基本的。(Nc)　電裝品越少 待命品越少的車 電池越耐用(Na)　GS蠻不錯的(FW)　看行駛路況，常短途跑一定壽命不長(Na)　新車出廠2y10m 還在服役(Na)　感覺偶爾開個長途，電瓶根本很難壞掉阿，隨便用都(Nb)　超過五年(Nd)　新車三年 舊車沒試過 舊車都用殺肉電瓶(Na)　AGM會不會比一般鉛酸電池耐用？(FW)　用五年 電壓看起來還行(Nc)　韓製不敢用 然後想用印度製？(Nb)　其實掛點的，用麻X慢充個四五天，能回充的，至少可以再用一個周期，只是很多新車無法斷電換電瓶，充滿(Nb)　風險(Na)　長紅燈進N檔，甚至關大燈，有助於市區的回充(Nb)　keyless有車庫，可進入省電模式(FW)　focusmk4 聽到很多一年半掛掉的(FW)　怠速熄火就是折磨電池(Na)　我下一顆打算試看看鋰鐵電池(Nb)　用過Varta  Deta  都超過三年(VC)　愛馬龍100D用了四年壽命剩50%車報廢拆下,放著一年半(Nb)　之後去測還有38%(Nb)　11年了還沒換過(Nd)
# (42, 45, 'CARDINAL', '一年半')
# (100, 102, 'DATE', '3年')
# (196, 198, 'DATE', '兩年')
# (230, 234, 'DATE', '五年八年')
# (319, 325, 'DATE', '五年新車三年')
# (357, 359, 'DATE', '五年')
# (393, 396, 'DATE', '四五天')
# (557, 560, 'TIME', '一年半')
# (566, 572, 'DATE', '38%11年')
#
# '['[', '菜單', '] Ford kuga ', '180', '旗艦', ' - ', '看板', ' car - ', '批踢踢', '實業坊', ':', '車輛', '廠牌', '/', '年份', '/', '型號', '：', '福特', '/', '2020年式', '\n', '車輛', '原廠', '編成', '等級', '：', '180', '旗艦', '\n', '是否', '含', '保險', '：', '無', '\n', '是否', '含', '領牌', '稅金', '：', '無', '\n', '成交', '價格', '(', '總價', ')', ':', ' 100', '.', '9萬', '（', '未', '扣舊', '換新', '5萬', '廢鐵', '1萬', '）', '\n']'
# [(PARENTHESISCATEGORY)　菜單(Na)　] Ford kuga (FW)　180(Neu)　旗艦(Na)　 - (FW)　看板(Na)　 car - (FW)　批踢踢(Na)　實業坊(Nc)　:(COLONCATEGORY)　車輛(Na)　廠牌(Na)　/(FW)　年份(Na)　/(FW)　型號(Na)　：(COLONCATEGORY)　福特(Nb)　/(FW)　2020年式(Nb)
# (WHITESPACE)　車輛(Na)　原廠(Nc)　編成(VG)　等級(Na)　：(COLONCATEGORY)　180(Neu)　旗艦(Na)
# (WHITESPACE)　是否(D)　含(VC)　保險(Na)　：(COLONCATEGORY)　無(VJ)
# (WHITESPACE)　是否(D)　含(VC)　領牌(VA)　稅金(Na)　：(COLONCATEGORY)　無(VJ)
# (WHITESPACE)　成交(Nv)　價格(Na)　((PARENTHESISCATEGORY)　總價(Na)　)(PARENTHESISCATEGORY)　:(COLONCATEGORY)　 100(FW)　.(PERIODCATEGORY)　9萬(Neu)　（(PARENTHESISCATEGORY)　未(D)　扣舊(VH)　換新(VC)　5萬(Neu)　廢鐵(Na)　1萬(Neu)　）(PARENTHESISCATEGORY)
# (WHITESPACE)
# (50, 52, 'ORG', '福特')
# (115, 117, 'CARDINAL', '5萬')
#
# '['折超多的', '新竹地區問，折6.5-7萬，但是你有送的東西都要自己', '掏腰包...果然買車還是要去台北/桃園...', '之前在新竹問空車折6.5，其餘都自費', '滿神的 加送的東西應該折到8萬 不過這業務有賺嗎...', '還是年底拼業績？', '這不只8萬了吧？延長保固就值1萬了！行車記錄器就8千+隔熱紙1萬多。這業務太佛了吧', '延長保固有兩種，這種應該是6500的']'
# 折超多的(VA)　新竹地區問，折6.5-7萬，但是你有送的東西都要自己(Nc)　掏腰包...果然買車還是要去台北/桃園...(VA)　之前在新竹問空車折6.5，其餘都自費(Nb)　滿神的 加送的東西應該折到8萬 不過這業務有賺嗎...(VH)　還是年底拼業績？(Nd)　這不只8萬了吧？延長保固就值1萬了！行車記錄器就8千+隔熱紙1萬多。這業務太佛了吧(VH)　延長保固有兩種，這種應該是6500的(VH)
# (4, 8, 'GPE', '新竹地區')
# (11, 17, 'CARDINAL', '6.5-7萬')
# (24, 27, 'GPE', '東西都')
# (44, 46, 'GPE', '台北')
# (47, 49, 'GPE', '桃園')
# (55, 57, 'GPE', '新竹')
# (61, 64, 'CARDINAL', '6.5')
# (77, 79, 'GPE', '東西')
# (83, 85, 'CARDINAL', '8萬')
# (108, 110, 'CARDINAL', '8萬')
# (119, 121, 'CARDINAL', '1萬')
# (129, 131, 'CARDINAL', '8千')
# (135, 138, 'CARDINAL', '1萬多')
# (159, 163, 'CARDINAL', '6500')
#
# '['[', '問題', '] ', '藍芽', '發射器', '有', '某些', '路段', '會', '有', '雜音', ' - ', '看板', ' car - ', '批踢踢', '實業坊', ':', '  ', '車子', '的', '藍芽', '發射器', '是', '朋友', '給', '的', '，', '是', '裝', '在', '點菸器', '上', '的', '那', '種', '，', '一直', '以來', '在', '某些', '路段', '都', '會', '有', '雜\n', ' 音', '，', '甚至', '還可以', '聽到', '不', '知名', '的', '音訊', '，', '好像', '是', '訊號', '不', '夠', '強', '被', '蓋', '台', '的', '那', '種', '感覺', '，', '想', '請問', '是', '因', '\n ', '為', '我', '的', '藍芽', '發射器', '檔次', '不', '夠', '，', '還是', '我', '使用', '的', '方式', '不', '對', '?', ' ', '車子', '是', '馬三', '所以', '好像', '沒有', '其他', '方式', '\n ', '可以', '讓', '我', '聽', '手機', '的', 'spotify', '了', 'QQ ', '跪求', '大家', '給', '我', '解決', '的', '方案', '\n--\n']'
# [(PARENTHESISCATEGORY)　問題(Na)　] (FW)　藍芽(Na)　發射器(Na)　有(V_2)　某些(Neqa)　路段(Na)　會(D)　有(V_2)　雜音(Na)　 - (FW)　看板(Na)　 car - (FW)　批踢踢(Na)　實業坊(Nc)　:(COLONCATEGORY)　  (WHITESPACE)　車子(Na)　的(DE)　藍芽(Na)　發射器(Na)　是(SHI)　朋友(Na)　給(VD)　的(T)　，(COMMACATEGORY)　是(SHI)　裝(VC)　在(P)　點菸器(Na)　上(Ncd)　的(DE)　那(Nep)　種(Nf)　，(COMMACATEGORY)　一直(D)　以來(Ng)　在(P)　某些(Neqa)　路段(Na)　都(D)　會(D)　有(V_2)　雜
# (Na)　 音(FW)　，(COMMACATEGORY)　甚至(D)　還可以(D)　聽到(VE)　不(D)　知名(VH)　的(DE)　音訊(Na)　，(COMMACATEGORY)　好像(D)　是(SHI)　訊號(Na)　不(D)　夠(Dfa)　強(VH)　被(P)　蓋(VC)　台(Nc)　的(DE)　那(Nep)　種(Nf)　感覺(Na)　，(COMMACATEGORY)　想(VE)　請問(VE)　是(SHI)　因(Cbb)
#  (WHITESPACE)　為(P)　我(Nh)　的(DE)　藍芽(Na)　發射器(Na)　檔次(Na)　不(D)　夠(VH)　，(COMMACATEGORY)　還是(Caa)　我(Nh)　使用(VC)　的(DE)　方式(Na)　不(D)　對(VH)　?(QUESTIONCATEGORY)　 (WHITESPACE)　車子(Na)　是(SHI)　馬三(Nb)　所以(Cbb)　好像(D)　沒有(VJ)　其他(Neqa)　方式(Na)
#  (WHITESPACE)　可以(D)　讓(VL)　我(Nh)　聽(VE)　手機(Na)　的(DE)　spotify(FW)　了(Di)　QQ (FW)　跪求(VE)　大家(Nh)　給(VD)　我(Nh)　解決(VC)　的(DE)　方案(Na)
# --
# (FW)
#
# '['應該是供電的聲音', '換個頻段', '這個大概是因為，你調的那個頻道，在那個區域也有廣播頻道，再換個頻道就好，不過賣藥電台真的很多，很', '容易開一開被蓋台車用的藍牙發射器如果頻道跟廣播電台接近，會變成兩', '個聲音一直交叉蓋台', '我有時候跟隔壁的車同頻道還會聽到他播的台語老歌勒', '這時候我就想說我音量轉大聲點能不能蓋台回去', '大家有推薦的頻段嗎?', '5G大數據時代影響', '沒有 就算有也不會講', '各地的電台頻段不一樣你在北部可以用到中部可能就被', '蓋台', '看你能不能接AUX吧', '那種可以調整頻段嗎  不是固定107.5嗎', '可以調啊,在範圍內你爽都行', '88.5.     87.9', '之前查過95.7好像沒有電台 所以我都用這頻段', '全車貼滿含金屬的隔熱紙…', '以前我都用87.5 or 108.0 或空的區段 較不會雜訊 山區、隧道就沒辦法啦']'
# 應該是供電的聲音(VH)　換個頻段(VH)　這個大概是因為，你調的那個頻道，在那個區域也有廣播頻道，再換個頻道就好，不過賣藥電台真的很多，很(VH)　容易開一開被蓋台車用的藍牙發射器如果頻道跟廣播電台接近，會變成兩(VH)　個聲音一直交叉蓋台(FW)　我有時候跟隔壁的車同頻道還會聽到他播的台語老歌勒(VH)　這時候我就想說我音量轉大聲點能不能蓋台回去(VA)　大家有推薦的頻段嗎?(VH)　5G大數據時代影響(FW)　沒有 就算有也不會講(VH)　各地的電台頻段不一樣你在北部可以用到中部可能就被(VH)　蓋台(VA)　看你能不能接AUX吧(VA)　那種可以調整頻段嗎  不是固定107.5嗎(FW)　可以調啊,在範圍內你爽都行(FW)　88.5.     87.9(Neu)　之前查過95.7好像沒有電台 所以我都用這頻段(Ng)　全車貼滿含金屬的隔熱紙…(Na)　以前我都用87.5 or 108.0 或空的區段 較不會雜訊 山區、隧道就沒辦法啦(Neu)
# (187, 189, 'GPE', '北部')
# (193, 195, 'GPE', '中部')
# (226, 231, 'CARDINAL', '107.5')
# (263, 267, 'CARDINAL', '95.7')
#
# '['[', '菜單', '] Ford Focus st-line lommel 4d - ', '看板', ' car - ', '批踢踢', '實業坊', ':', '以下', '為', '建議', '資訊', '\n捐虃t', '牌', '/', '年份', '/', '型號', '：', 'Ford  20', '.', '75年式', '\n', '車輛', '原廠', '編成', '等級', 'Gst-line lommel\n', '是否', '含', '保險', '：', '否\n', '是否', '含', '領牌', '稅金', '：', '否\n']'
# [(PARENTHESISCATEGORY)　菜單(Na)　] Ford Focus st-line lommel 4d - (FW)　看板(Na)　 car - (FW)　批踢踢(Na)　實業坊(Nc)　:(COLONCATEGORY)　以下(Ncd)　為(VG)　建議(VE)　資訊(Na)
# 捐虃t(VD)　牌(Na)　/(FW)　年份(Na)　/(FW)　型號(Na)　：(COLONCATEGORY)　Ford  20(Nb)　.(DOTCATEGORY)　75年式(Na)
# (WHITESPACE)　車輛(Na)　原廠(Nc)　編成(VG)　等級(Na)　Gst-line lommel
# (FW)　是否(D)　含(VC)　保險(Na)　：(COLONCATEGORY)　否
# (Nb)　是否(D)　含(VC)　領牌(VA)　稅金(Na)　：(COLONCATEGORY)　否
# (Nb)
#
# '['請問業代', '求業代求業代', '恭喜！ 求業代資訊', '求業務資訊，恭喜大大牽車', '  好屌', '請問是2021年嗎? 也太猛', '求業代 謝謝']'
# 請問業代(Na)　求業代求業代(Na)　恭喜！ 求業代資訊(Nb)　求業務資訊，恭喜大大牽車(Nb)　  好屌(Nb)　請問是2021年嗎? 也太猛(VE)　求業代 謝謝(Nb)
# (38, 43, 'DATE', '2021年')
#
# '['[', '問題', '] ', '原廠', '烤漆', '摸起來', '粗粗', '的', ' - ', '看板', ' car - ', '批踢踢', '實業坊', ':', '被', '追撞', '的', '車禍', ' ', '傷', '了', '後保', '桿\n', '結果', '回', '原廠', '處理', '換新', '保桿', '加', '烤漆\n', '剛剛', '發現', '保桿', '有', '烤漆', '的', '位置', '\n', '摸起來', '粗粗', '的', ' ', '有解', '嗎', '？', '\n', '還是', '要', '給', '美容', '拋光', '或是', '跑', '黏土', ' / ', '打蠟', '？', '\n']'
# [(PARENTHESISCATEGORY)　問題(Na)　] (FW)　原廠(Nc)　烤漆(Na)　摸起來(D)　粗粗(VH)　的(DE)　 - (FW)　看板(Na)　 car - (FW)　批踢踢(Na)　實業坊(Nc)　:(COLONCATEGORY)　被(P)　追撞(VC)　的(DE)　車禍(Na)　 (WHITESPACE)　傷(VHC)　了(Di)　後保(Na)　桿
# (Na)　結果(Na)　回(VCL)　原廠(Nc)　處理(VC)　換新(VC)　保桿(Na)　加(VC)　烤漆
# (Na)　剛剛(D)　發現(VE)　保桿(Na)　有(V_2)　烤漆(Na)　的(DE)　位置(Na)
# (WHITESPACE)　摸起來(D)　粗粗(VH)　的(DE)　 (WHITESPACE)　有解(VH)　嗎(T)　？(QUESTIONCATEGORY)
# (WHITESPACE)　還是(D)　要(D)　給(VD)　美容(VB)　拋光(VA)　或是(Caa)　跑(VA)　黏土(Na)　 / (FW)　打蠟(VA)　？(QUESTIONCATEGORY)
# (WHITESPACE)
#
# '['不明顯就不要理了啦，很在意就去給技術好的美容處理', '要求重烤', '原廠當然看是重烤還是怎麼處理 不是自己處理就對了', '美容做一做就好 應該是有點飛漆', '一堆原廠也是外包啦。']'
# 不明顯就不要理了啦，很在意就去給技術好的美容處理(VH)　要求重烤(VH)　原廠當然看是重烤還是怎麼處理 不是自己處理就對了(VH)　美容做一做就好 應該是有點飛漆(VH)　一堆原廠也是外包啦。(VH)
# (0, 3, 'PERSON', '不明顯')

# %%
import pandas as pd

count_list = []
# count_dict = {}
for e in entity_sentence_list:
    for i in e:
#         count_dict[i[3]] = count_dict.get(i[3], 0) + 1
#         df = pd.concat([df, pd.DataFrame(i[3])])
        count_list.append(i[3])

# %%
from collections import Counter
entity = Counter(count_list)
entity.most_common(5)
# Out:
# [('一年半', 2), ('8萬', 2), ('5.6', 1), ('韓國大盤館', 1), ('和泰', 1)]

# %%
df = pd.DataFrame(count_list, columns=["entity"])
text = df.entity.value_counts()
text.head(30)
# Out:
# 一年半       2
# 8萬        2
# 5.6       1
# 6500      1
# 5萬        1
# 兩年        1
# 桃園        1
# 6.5-7萬    1
# 韓國大盤館     1
# 福特        1
# 中古        1
# 2021年     1
# 國際牌       1
# 1萬        1
# 四五天       1
# 95.7      1
# 6.5       1
# 新竹地區      1
# 先清算       1
# 東西都       1
# 8千        1
# 五年八年      1
# 38%11年    1
# 民進黨       1
# 1萬多       1
# 和泰        1
# 不明顯       1
# 107.5     1
# 新竹        1
# 台北        1
# Name: entity, dtype: int64

# %%
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd

fq_count_lists = []
# count_dict = {}
for e in entity_sentence_list:
    fq_count_list = []
    for i in e:
#         count_dict[i[3]] = count_dict.get(i[3], 0) + 1
#         df = pd.concat([df, pd.DataFrame(i[3])])
        fq_count_list.append(i[3])
    fq_count_lists.append(fq_count_list)
te = TransactionEncoder()
te_ary = te.fit(fq_count_lists).transform(fq_count_lists)
df = pd.DataFrame(te_ary, columns=te.columns_)
from mlxtend.frequent_patterns import fpgrowth
  
fpgrowth(df, min_support=0.05, use_colnames=True)
# Out:
#       support               itemsets
# 0      0.0625                  (5.6)
# 1      0.0625                (韓國大盤館)
# 2      0.0625                   (和泰)
# 3      0.0625                  (民進黨)
# 4      0.0625                  (先清算)
# ...       ...                    ...
# 8473   0.0625          (107.5, 95.7)
# 8474   0.0625        (107.5, 中部, 北部)
# 8475   0.0625      (107.5, 北部, 95.7)
# 8476   0.0625      (107.5, 中部, 95.7)
# 8477   0.0625  (107.5, 中部, 北部, 95.7)
#
# [8478 rows x 2 columns]

# %%
python app.py  car  10
# Out:
#   File "<ipython-input-17-e5dccad10135>", line 1
#     python app.py  car  10
#            ^
# SyntaxError: invalid syntax
